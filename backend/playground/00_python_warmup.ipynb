# %% [markdown]
# # Playground 00 — Python warm-up 🛝
#
# **Run me first!**
#
# How to use a notebook:
#
# - Click a cell, press **Shift+Enter** (or the ▶ button) to run it. Output appears right below.
# - **Edit anything and re-run it.** That loop — change, run, compare — is the whole point.
# - Cells share memory top-to-bottom. If things get confused, use **Run All** from the menu to start fresh.
#
# Five tiny ideas below — variables, lists, dictionaries, loops, functions — that every later notebook (and the whole project) is built from.

# %% [markdown]
# ## 1. Variables — a name stuck on a value

# %%
brand = "Chanel"            # text  (called a "string", or str)
price = 9500.0              # a decimal number (a "float")
year = 2026                 # a whole number (an "int")
is_sold_out = False         # True or False (a "bool")

# An f-string lets you drop variables into text with {curly braces}:
print(f"A {brand} bag costs ${price} in {year}. Sold out? {is_sold_out}")

# %% [markdown]
# ## 2. Lists — an ordered row of values

# %%
prices = [9500.0, 9800.0, 9650.0]   # square brackets = list

print(f"all prices:        {prices}")
print(f"first price:       {prices[0]}")    # counting starts at 0!
print(f"last price:        {prices[-1]}")   # -1 means 'from the end'
print(f"how many prices:   {len(prices)}")

prices.append(9900.0)                       # add to the end
print(f"after append:      {prices}")

# %% [markdown]
# ## 3. Dictionaries — values looked up by name, not position
#
# A dict maps a **key** to a **value**. Like a contacts app: name → number.

# %%
bag = {
    "id": "chanel-flap-001",
    "brand": "Chanel",
    "model": "Classic Flap Medium",
    "price": 9500.0,
}

print(f"the whole dict:    {bag}")
print(f"just the brand:    {bag['brand']}")   # look up by key

bag["color"] = "Black Caviar"                 # add a new key
bag["price"] = 9800.0                         # overwrite an existing one
print(f"after editing:     {bag}")

# %% [markdown]
# ## 4. Loops — do something to every item

# %%
bags = ["chanel-flap-001", "lv-neverfull-001", "hermes-birkin-001"]

for bag_id in bags:                  # 'bag_id' takes each value in turn
    if bag_id.startswith("chanel"):  # 'if' = only sometimes
        print(f"  {bag_id}   <-- it's a Chanel!")
    else:
        print(f"  {bag_id}")

# %% [markdown]
# ## 5. Functions — a recipe with a name
#
# `def` defines a function: inputs in parentheses, result after `return`.

# %%
def price_drop(old_price, new_price):
    # How many dollars cheaper did it get?
    return old_price - new_price

drop = price_drop(9800.0, 9500.0)    # 'calling' the function
print(f"price_drop(9800, 9500) = {drop}")
print(f"price_drop(100, 250)   = {price_drop(100.0, 250.0)}  (negative = it got pricier)")

# %% [markdown]
# ## ✏️ Your turn
#
# Each exercise has its own cell below. Edit, run, compare.

# %%
# Exercise 1: change `brand` to YOUR dream bag's brand, then run.
brand = "Chanel"
print(f"My dream bag is by {brand}")

# %%
# Exercise 2: PREDICT which number this prints BEFORE running it.
# (Remember: counting starts at 0.) Then run and check yourself.
prices = [9500.0, 9800.0, 9650.0]
print(prices[1])

# %%
# Exercise 3: run this cell and READ the error message (a KeyError —
# 'size' isn't a key in the dict). Then fix it: change 'size' to a key
# that exists, like 'brand', and run again.
# Errors are normal — reading them calmly is half of programming.
print(bag["size"])

# %%
# Exercise 4: finish this function so the two checks below print
# True and then False.
def is_expensive(price):
    ...   # replace ... with:  return price > 5000

print(is_expensive(9500.0))   # should print True
print(is_expensive(120.0))    # should print False
